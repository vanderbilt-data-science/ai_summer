# %% [markdown]
# <a href="https://colab.research.google.com/github/vanderbilt-data-science/ai_summer/blob/main/4_2_phi_vision_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inferencing with Phi
#
# Access the HuggingFace space here: https://huggingface.co/microsoft/Phi-3-vision-128k-instruct
#
# Be sure you are connected to the A100 or L4 GPU on Colab.

# %%
# !pip install -q transformers
# !pip install -q flash_attn
# !pip install -q accelerate
# !pip install -q torch
# !pip install -q torchvision
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 38.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 65.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 8.1 MB/s eta 0:00:00

# %%
from PIL import Image
import requests
from transformers import AutoModelForCausalLM
from transformers import AutoProcessor

model_id = "microsoft/Phi-3-vision-128k-instruct"

model = AutoModelForCausalLM.from_pretrained(model_id, device_map="cuda", trust_remote_code=True, torch_dtype="auto")

processor = AutoProcessor.from_pretrained(model_id, trust_remote_code=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/3.66k [00:00<?, ?B/s]
# configuration_phi3_v.py:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-vision-128k-instruct:
# - configuration_phi3_v.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %% [markdown]
# ![Image of a chart](https://assets-c4akfrf5b4d3f4b7.z01.azurefd.net/assets/2024/04/BMDataViz_661fb89f3845e.png)

# %%
messages = [
    {"role": "user", "content": "<|image_1|>\nWhat is shown in this image?"}
]

url = "https://assets-c4akfrf5b4d3f4b7.z01.azurefd.net/assets/2024/04/BMDataViz_661fb89f3845e.png"
image = Image.open(requests.get(url, stream=True).raw)

prompt = processor.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

inputs = processor(prompt, [image], return_tensors="pt").to("cuda:0")

generation_args = {
    "max_new_tokens": 500,
    "temperature": 0.0,
    "do_sample": False,
}

generate_ids = model.generate(**inputs, eos_token_id=processor.tokenizer.eos_token_id, **generation_args)

# remove input tokens
generate_ids = generate_ids[:, inputs['input_ids'].shape[1]:]
response = processor.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

print(response)
# Out:
# The image displays a bar chart showing the percentage of respondents who agree with various statements about their preparedness for meetings. The chart has five vertical bars, each representing a different statement, with percentages ranging from 75% to 79%. The statements are about having clear and pre-defined goals for meetings, knowing where to find information for a meeting, understanding one's exact role and responsibilities when invited, having tools to manage admin tasks like note-taking or summarization, and having more focus time to sufficiently prepare for meetings. The source of the data is Microsoft WorkLab.

# %% [markdown]
# That's nice, but let's try it on an image it definitely hasn't seen. In this case I'm going to upload my own picture of my cat. Upload an image to Colab by using the sidebar folder icon -> upload. Be sure your image filename matches the path in the below code cell.

# %%
path = "./my_image.jpg" # BE SURE TO UPLOAD AN IMAGE TO YOUR COLAB INSTANCE :)
image = Image.open(path)

# %% [markdown]
# Alternatively, you can use my image from GitHub.
#
#
# <img src="https://github.com/vanderbilt-data-science/ai_summer/raw/main/img/cloud.jpg" alt="my image from github" width="200">

# %%
# uncomment if you will use image from GitHub
#url = "https://github.com/vanderbilt-data-science/ai_summer/raw/main/img/cloud.jpg"
#image = Image.open(url)

# %%
prompt = processor.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

inputs = processor(prompt, [image], return_tensors="pt").to("cuda:0")

generation_args = {
    "max_new_tokens": 500,
    "temperature": 0.0,
    "do_sample": False,
}

generate_ids = model.generate(**inputs, eos_token_id=processor.tokenizer.eos_token_id, **generation_args)

# remove input tokens
generate_ids = generate_ids[:, inputs['input_ids'].shape[1]:]
response = processor.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

print(response)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# The image shows a Siamese cat lying on its back on a carpeted floor, with its paws up in the air and its head tilted upwards, looking upwards.

# %% [markdown]
# Try something a bit more fun...

# %%
messages = [
    {"role": "user", "content": "<|image_1|>\nWhat is shown in this image?"},
    {"role": "user", "content": "Write an instagram post to go with this picture"}
]

# %%
prompt = processor.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

inputs = processor(prompt, [image], return_tensors="pt").to("cuda:0")

generation_args = {
    "max_new_tokens": 500,
    "temperature": 0.0, # play around with temperature for a more creative post
    "do_sample": False,
}

generate_ids = model.generate(**inputs, eos_token_id=processor.tokenizer.eos_token_id, **generation_args)

# remove input tokens
generate_ids = generate_ids[:, inputs['input_ids'].shape[1]:]
response = processor.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

print(response)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# 🐱 This little feline friend is taking a well-deserved nap under a cozy blanket. Their soft paws and adorable blue eyes make this moment even more precious. 💕 #CatLover #PetLovers #CutePets #FurryFriend #PetPhotography #CuddleTime #PetAdventures #CatLife #PetMemories #PetLoversClub #CatPhotography #CatPhotographyTips #CatPhotographyTipsAndTricks #CatPhotographyTipsAndTricksAndTips #CatPhotographyTipsAndTricksAndTipsAndTricks #CatPhotographyTipsAndTricksAndTipsAndTricksAndTipsAndTricks #...

# %%
prompt = processor.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

inputs = processor(prompt, [image], return_tensors="pt").to("cuda:0")

generation_args = {
    "max_new_tokens": 500,
    "temperature": 0.8, # play around with temperature for a more creative post
    "do_sample": True,
}

generate_ids = model.generate(**inputs, eos_token_id=processor.tokenizer.eos_token_id, **generation_args)

# remove input tokens
generate_ids = generate_ids[:, inputs['input_ids'].shape[1]:]
response = processor.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

print(response)
# Out:
# 🐱 Cozy corner of my life: little Siamese kitty named Whiskers. 🌟 Just discovered that despite their name, Siamese cats are actually from Thailand and not their own breed. It's always fascinating learning about our feline friends! 🌀 What's the most surprising thing you've learned about a pet today? 🐾 #CatLover #PetFacts #Thailand
